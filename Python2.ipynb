# %% [markdown]
# <a href="https://colab.research.google.com/github/HusainAhmadKhan/Python-Practise/blob/main/Python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="python"
print(len(a)) #to print length use print keyword before len(a)
print(a[1])
print(a[2])
print(a[3])
print(a[4])
print(a[5])
print(a[0:6]) #last value is exclusive that's why 1 is added
# Out:
# 6
# y
# t
# h
# o
# n
# python

# %%
a="hello world! "
print(a[6:11])
print(a[1:len(a):2]) #1 means start from index 1 : len function to read whole length : 2 means alternate OR SYNTAX= starting:ending:steps
print(a[0:11:3])
#by default index is 0: by default is length: by default is 1 step
print(a[ : : ])
print(a[ : :3])
print(a[: :4])#to print every 4th letter of string
print(a[ : :-1])
# Out:
# world
# el ol!
# hlwl
# hello world!
# hlwl
# hor
#  !dlrow olleh

# %%
a="helloworld!"
print(a[-1])
print(a[-6:-1])#to print world
print(a[-2:-7:-1])#to print world in reverse order
# Out:
# !
# world
# dlrow

# %%
#program to input the name and reverse it
x=f"{input("Enter your first name:")}"
print(x[: :-1])
# Out:
# Enter your first name:husain
# niasuh

# %%
#program to input the name and reverse it in one line
print(f"your reversed name {input("Enter your name: ")[::-1]}")
# Out:
# Enter your name: husian
# your reversed name naisuh

# %%
a="Hello, World!"
print(a.upper())#ALL CAPITAL
print(a.lower())#all small
print(a.strip())#remove extra spaces in start and end
print(a.replace("H","J"))#replaces
print(a.split(","))#splits the word   #for example split main jitne comma ayenge tou no. of commas+1 splitting hogi
print(a.capitalize())#capitalizes fist letter
print(a.replace("Hello","Trello"))
print(a.count("H"))#counts the occurences of passed alphabet in a string
# Out:
# HELLO, WORLD!
# hello, world!
# Hello, World!
# Jello, World!
# ['Hello', ' World!']
# Hello, world!
# Trello, World!
# 1

# %%
full_name="husain,ahmad,khan"
first_name, middle_name, last_name=full_name.split(",")
print(first_name)
print(middle_name)
print(last_name)
# Out:
# husain
# ahmad
# khan

# %%
#program to take 2 inputs as comma separated values from user and a single character from the name and count the character present in the given name
# name,char=f"{input("Enter your name:")}".split(",") #fstring formatting done here
name,char=input("Enter your name:").split(",")
name.count(char)
# Out:
# Enter your name:husain,i
# 1

# %%
#comparison operators
#type should be same for comparison
a=5
b=2
c=5
d=6
e="husain" #compares code of character
f="ahmad"
print(e==f)
print(e<=f)
print(f<e)
print(a<=b)
print(a==c)
print(a!=c)
print(b>c)
print(c>b)
# Out:
# False
# False
# True
# False
# True
# False
# False
# True

# %%
#logical
x=15
print(x>10 and x<20)
print(x>10 or x<14)
print(not(x>16))
print(x==15 and x>20)
not(False) #this returns true
# Out:
# True
# True
# True
# False
# True

# %%
#Identity Operators
#is equivalent to ==
#is not equivalent to !=
x="1"
y=1
print(x is y)
print(y is not x)
# Out:
# False
# True

# %%
#Membership Operators
x="Husain Ahmad Khan"
y="Ahmad"
print("sain" in x)
print("z" not in x)
print("i" not in x)
print(y in x)
# Out:
# True
# True
# False
# True

# %%
#examples
x=10
y=20
print("x>y is ",x>y) #comparison operator /// same goes with logical....
# Out:
# x>y is  False

# %%
#typecasting
x=str(3)
print(x)
x=int(3)
print(x)
x=float(3)
print(x)
x=complex(3)
print(x)
# Out:
# 3
# 3
# 3.0
# (3+0j)

# %%
a=5j
type(a)
complex(4,5) #first real part then imaginary
# Out:
# (4+5j)

# %%
#any operation done with float answer will be in float
num_int=5
num_float=3.2
result=num_int+num_float
type(result)
result=num_int-num_float
type(result)
result=num_int*num_float
type(result)
result=num_int/num_float
type(result)
result=num_int%num_float
type(result)
# Out:
# float

# %%
#String concatenation
first_name="Husain"
last_name="Ahmad"
print(first_name+" "+last_name)
