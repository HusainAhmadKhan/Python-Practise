# %% [markdown]
# <a href="https://colab.research.google.com/github/HusainAhmadKhan/Python-Practise/blob/main/Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fstring method this is easier
a=23
exponential=a**5
print("exponential={}".format(exponential))

modls=a%5
print("modulus={}".format(modls))

floor_div=a//5
print("floor division={}".format(floor_div))

print(f"integer part={floor_div} and remainder={modls}")
# Out:
# exponential=6436343
# modulus=3
# floor division=4
# integer part=4 and remainder=3

# %%
a=23
exponential=a**5
print("exponential={}".format(exponential))

modls=a%5
print("modulus={}".format(modls))

floor_div=a//5
print("floor division={}".format(floor_div))

print("integer part={} and remainder={}".format(floor_div,modls))
# Out:
# exponential=6436343
# modulus=3
# floor division=4
# integer part=4 and remainder=3

# %%
#modulo to find remainder
#modulo symbol is %
a=23
a%5
# Out:
# 3

# %%
#exponential or power
a=5
a**2
# Out:
# 25

# %%
#by sir
#This should be used   .format wala use krna hai
#.format is a function of string(It places values orderly)
a=20
b=3
print("value a={} and value b={}".format(a,b))
c=a*b
d=a/b
e=a-b
f=a+b
print("Multiplication={}".format(c))
print("Division={}".format(d))
print("Subtraction={}".format(e))
print("Addition={}".format(f))
# Out:
# value a=20 and value b=3
# Multiplication=60
# Division=6.666666666666667
# Subtraction=17
# Addition=23

# %%
#done by me .... don't use this method
a=20
b=3
print("value a={} and value b={}".format(a,b))
z=a*b
print("Multiplication:",z)
z=a/b
print("Division:",z)
z=a-b
print("Subtraction:",z)
z=a+b
print("Addition:",z)
# Out:
# value a=20 and value b=3
# Multiplication: 60
# Division: 6.666666666666667
# Subtraction: 17
# Addition: 23

# %%
name="Husain"
age=21
print("Hello {} your age is {}".format(name,age))
# Out:
# Hello Husain your age is 21

# %%
print("Love" in "Love myPakistan")
# Out:
# True

# %%
print("Love" in "Pakistan")
# Out:
# False

# %%
x=int(input("Enter your date of birth:"))
y=int(input("Enter current year"))
z=y-x
print(z)
# Out:
# Enter your date of birth:2004
# Enter current year2025
# 21

# %%
print("Husain\nAhmad")
# Out:
# Husain
# Ahmad

# %%
print("Husain\tAhmad Khan")
# Out:
# Husain	Ahmad Khan

# %%
print("Husain\\husain")
# Out:
# Husain\husain

# %%
print("Husain\b Ahmad Khan")
# Out:
#  Ahmad Khan

# %%
print("Husain\"Ahmad\"Khan")
# Out:
# Husain"Ahmad"Khan

# %%
type("hello")
type(55)
type(1j)
type(22.5)
# Out:
# float

# %%
a="Hello world"
print(a) #agr direct a print kroge tou 'Hello world print hoga
# Out:
# Hello world

# %%
a="Rayyan Ibrahim"
print(len(a))
# Out:
# 14

# %%
print("Husain\'s Program")
# Out:
# Husain's Program

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# PEMDAS

# %%
#PEMDAS(PARENTHESIS EXPONENTIAL MULTIPLICATION DIVISION ADDITION SUBTRACTION)
a=(5+3)*4**2/2+5-2
print(a)
# Out:
# 67.0

# %% [markdown]
# TASK

# %%
a=int(input("Enter value of a:"))
b=int(input("Enter value of b:"))
c=int(input("Enter value of c:"))
question1=c*(a**2-b**2)
question2=((a-b)**3 + (a-c)**3)/((b-c)**2)
print(f"Question 1 answer is {question1}")
print(f"Question 2 answer is {question2}")
# Out:
# Enter value of a:7
# Enter value of b:5
# Enter value of c:2
# Question 1 answer is 48
# Question 2 answer is 14.777777777777779

# %%
#input three numbers and compute their average
a=int(input("Enter value of a:"))
b=int(input("Enter value of b:"))
c=int(input("Enter value of c:"))
average=(a+b+c)/3
print(f"Average of the number are {average}")
# Out:
# Enter value of a:50
# Enter value of b:21
# Enter value of c:22
# Average of the number are 31.0

# %%
#area of circle
radius=int(input("Enter radius of circle:"))
area=3.14*radius**2
print(f"area of circle is {area}")
# Out:
# Enter radius of circle:5
# area of circle is 78.5

# %%
#input three numbers in float and compute their average
a=float(input("Enter value of a:"))
b=float(input("Enter value of b:"))
c=float(input("Enter value of c:"))
average=(a+b+c)/3
print(f"Average of the number are {average}")
# Out:
# Enter value of a:66.3
# Enter value of b:22.3
# Enter value of c:11.2
# Average of the number are 33.266666666666666

# %%
#area of circle in float
radius=float(input("Enter radius of circle:"))
pi=3.14
area=pi*radius**2
print(f"area of circle is {area}")
# Out:
# Enter radius of circle:7.5
# area of circle is 176.625

# %%
#all 7 operations
a=float(input("Enter value of a:"))
b=float(input("Enter value of b:"))
print(f"value a={a} and value b={b}")
c=a*b
d=a/b
e=a-b
f=a+b
g=a**b
h=a%b
i=a//b
print(f"Multiplication={c}")
print(f"Division={d}")
print(f"Subtraction={e}")
print(f"Addition={f}")
print(f"Power={g}")
print(f"Modulus={h}")
print(f"Floor Division={i}")
# Out:
# Enter value of a:7.2
# Enter value of b:3.6
# value a=7.2 and value b=3.6
# Multiplication=25.92
# Division=2.0
# Subtraction=3.6
# Addition=10.8
# Power=1220.104382726576
# Modulus=0.0
# Floor Division=2.0
