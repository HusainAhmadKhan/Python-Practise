# %% [markdown]
# <a href="https://colab.research.google.com/github/HusainAhmadKhan/Python-Practise/blob/main/Car_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Husain")
# Out:
# Husain

# %%
import pandas as pd

# %%
df=pd.read_csv("car_data (1).csv")

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.head(12)
# Out:
#      Make                      Model    Type  Origin DriveTrain      MSRP  \
# 0   Acura                        MDX     SUV    Asia        All  $36,945
# 1   Acura             RSX Type S 2dr   Sedan    Asia      Front  $23,820
# 2   Acura                    TSX 4dr   Sedan    Asia      Front  $26,990
# 3   Acura                     TL 4dr   Sedan    Asia      Front  $33,195
# 4   Acura                 3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5   Acura    3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6   Acura     NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 7    Audi                A4 1.8T 4dr   Sedan  Europe      Front  $25,940
# 8    Audi     A41.8T convertible 2dr   Sedan  Europe      Front  $35,940
# 9    Audi                 A4 3.0 4dr   Sedan  Europe      Front  $31,840
# 10   Audi  A4 3.0 Quattro 4dr manual   Sedan  Europe        All  $33,430
# 11   Audi    A4 3.0 Quattro 4dr auto   Sedan  Europe        All  $34,480
#
# ...

# %%
df.tail() ##We can directly know rows from df.tail(). tail last row is 431. plus 1 in 431 gives you no. of rows.    no need of df.shape
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
df.shape
# Out:
# (432, 15)

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df_updated=df.dropna().copy()
df_updated.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df_updated.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.shape
# Out:
# (432, 15)

# %%
df_updated.shape
# Out:
# (426, 15)

# %%
df_updated.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df_updated["Origin"].value_counts()
# Out:
# Origin
# Asia      156
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
df_updated[["Type","Origin","Model"]].value_counts()
# Out:
# Type   Origin  Model
# Sedan  Asia    G35 4dr                      2
#        Europe  C240 4dr                     2
#                C320 4dr                     2
#        USA     Neon SXT 4dr                 1
#                Neon SE 4dr                  1
#                                            ..
#        Asia    Quest SE                     1
#                Quest S                      1
#                Q45 Luxury 4dr               1
#                Outback Limited Sedan 4dr    1
#                Sonata GLS 4dr               1
# Name: count, Length: 423, dtype: int64

# %%
df_updated.Origin.value_counts() #We can only access 1 column using this
# Out:
# Origin
# Asia      156
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
df_updated[df_updated["Origin"]=="Asia"] #Shows only the rows where the origin is Asia.
# Out:
#        Make                       Model    Type Origin DriveTrain      MSRP  \
# 0     Acura                         MDX     SUV   Asia        All  $36,945
# 1     Acura              RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2     Acura                     TSX 4dr   Sedan   Asia      Front  $26,990
# 3     Acura                      TL 4dr   Sedan   Asia      Front  $33,195
# 4     Acura                  3.5 RL 4dr   Sedan   Asia      Front  $43,755
# ..      ...                         ...     ...    ...        ...       ...
# 400  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 401  Toyota                      Tacoma   Truck   Asia       Rear  $12,800
# 402  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear  $16,495
# 403  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All  $25,935
# 404  Toyota                   Matrix XR   Wagon   Asia      Front  $16,695
#
# ...

# %%
temp=df_updated[df_updated["Origin"]=="USA"] #Stores only the rows where the origin is in USA in temp variable.
temp.shape
# Out:
# (147, 15)

# %%
USAorEurope=df_updated[(df_updated.Origin=="USA") | (df_updated.Origin=="Europe")]
USAorEurope["Origin"].value_counts()
# Out:
# Origin
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
df_updated.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
greater_4000=df_updated[df_updated["Weight"]>4000]
greater_4000.shape
# Out:
# (103, 15)

# %%
less_4000=df_updated[~(df_updated["Weight"]>4000)]  #negation used here ~
print(less_4000["Weight"].max())
print(less_4000["Weight"].min())
# df_updated[df_updated["Weight"]>3000].value_counts()  . Just for practise
# Out:
# 3992.0
# 1850.0

# %%
df_updated["MPG_City"]=df_updated["MPG_City"]+3

# %%
df_updated.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      20.0         23.0  4451.0
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0
